# %% [markdown]
# <a href="https://colab.research.google.com/github/dimitrod/ehu_nlp_dimathina/blob/Evaluation/Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets

# %%
import datasets
from datasets import load_dataset
import json

# %%
evaluation_data = load_dataset('trivia_qa', name='rc.wikipedia', split="train[:7900]")
# Out:
# Resolving data files:   0%|          | 0/26 [00:00<?, ?it/s]

# %%
file = "{\"Data\":["
i=1
for entry in evaluation_data:
    print(f"loading file {i} of {len(evaluation_data)}")
    file += json.dumps(entry)
    if i < len(evaluation_data) :
        file += ",\n"
    else :
        file += "],\n"
    i += 1
file += "\"Domain\": \"Wikipedia\",\"VerifiedEval\": false,\"Version\": 1.0}"
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# loading file 2901 of 7900
# loading file 2902 of 7900
# loading file 2903 of 7900
# loading file 2904 of 7900
# loading file 2905 of 7900
# loading file 2906 of 7900
# loading file 2907 of 7900
# loading file 2908 of 7900
# loading file 2909 of 7900
# loading file 2910 of 7900
# loading file 2911 of 7900
# loading file 2912 of 7900
# loading file 2913 of 7900
# loading file 2914 of 7900
# loading file 2915 of 7900
# loading file 2916 of 7900
# loading file 2917 of 7900
# loading file 2918 of 7900
# loading file 2919 of 7900
# loading file 2920 of 7900
# loading file 2921 of 7900
# loading file 2922 of 7900
# loading file 2923 of 7900
# loading file 2924 of 7900
# loading file 2925 of 7900
# loading file 2926 of 7900
# loading file 2927 of 7900
# loading file 2928 of 7900
# loading file 2929 of 7900
# loading file 2930 of 7900
# loading file 2931 of 7900
# loading file 2932 of 7900
# loading file 2933 of 7900
# ...

# %%
file = file.replace("normalized_matched_wiki_entity_name", "NormalizedMatchedWikiEntityName")
file = file.replace("matched_wiki_entity_name", "MatchedWikiEntityName")
file = file.replace("normalized_aliases", "NormalizedAliases")
file = file.replace("normalized_value", "NormalizedValue")
file = file.replace("question_source", "QuestionSource")
file = file.replace("search_results", "SearchResults")
file = file.replace("entity_pages", "EntityPages")
file = file.replace("description", "Description")
file = file.replace("question_id", "QuestionId")
file = file.replace("doc_source", "DocSource")
file = file.replace("filename", "Filename")
file = file.replace("question", "Question")
file = file.replace("aliases", "Aliases")
file = file.replace("answer", "Answer")
file = file.replace("value", "Value")
file = file.replace("title", "Title")
file = file.replace("title", "Title")
file = file.replace("rank", "Rank")
file = file.replace("type", "Type")
file = file.replace("url", "Url")

# %%
data = json.loads(file)

# %%
for i in range(len(data['Data'])):
  del data['Data'][i]["EntityPages"]["wiki_context"]

# %%
file = json.dumps(data)

# %%
with open(f"evaluation_data.json","w") as f:
    f.write(file)
